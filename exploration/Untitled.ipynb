# %%
import nltk
import gensim
from gensim.models import Word2Vec

# %%
sentence = "ich bin ein endstern"

# %%
model = gensim.models.KeyedVectors.load_word2vec_format('/Users/hao/Downloads/german.model', binary=True)

# %%
model.index2word
# Out:
# ['Die',
#  'fuer',
#  'wurde',
#  'Der',
#  'dass',
#  'Das',
#  'ueber',
#  'In',
#  'Im',
#  'wurden',
#  'Er',
#  'Sie',
#  'Jahr',
#  'mehr',
#  'zwei',
#  'Es',
#  'Nach',
#  'sowie',
#  'ab',
#  'Jahren',
#  'Jahre',
#  'sei',
#  'Am',
#  'beim',
#  'drei',
#  'seit',
#  'koennen',
#  'schon',
#  'Euro',
#  'Stadt',
#  'Mit',
#  'ersten',
#  'Ein',
#  'Auch',
#  'gibt',
#  'etwa',
#  'bereits',
#  'jedoch',
#  'Zeit',
#  'immer',
#  'Uhr',
#  'Als',
#  'Bei',
#  '1',
#  'Ende',
#  'heute',
#  'Fuer',
#  'sagte',
#  'Von',
#  'konnte',
#  'worden',
#  'sagt',
#  'Und',
#  'Eine',
#  'Prozent',
#  'Wir',
#  'kam',
#  'neue',
#  'Deutschland',
#  'gab',
#  'erste',
#  'vier',
#  'spaeter',
#  'Menschen',
#  'beiden',
#  'liegt',
#  'neuen',
#  'So',
#  'dabei',
#  '20',
#  'Diese',
#  'viele',
#  'steht',
#  'Ich',
#  'Auf',
#  'geht',
#  '2',
#  'rund',
#  'Mai',
#  'gut',
#  'Seit',
#  'zurueck',
#  'September',
#  'erst',
#  'Juni',
#  'August',
#  'Berlin',
#  '15',
# ...
