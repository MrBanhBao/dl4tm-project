# %%
import lyricsgenius
import os

# %%
genius = lyricsgenius.Genius('C4lb2FuFPCOkthatVzo3IuuVTJO_a2Q5sOd6_tI2Z1EabzHfvxcj15pJ1H-PivEX')

# %%
artists_80es = [
    'Run-D.M.C.',
    'Beastie Boys',
    'LL Cool J',
    'Big Daddy Kane',
    'Ice T',
    'Rakim',
    'Biz Markie'
]

artists_90es = [
    '2Pac',
    'The Notorious B.I.G.',
    'Busta Rhymes',
    'Snoop Dogg',
    'DMX',
    'Outkast',
    'Puff Daddy',
    'Ice Cube',
    'Jay Z',
    'Nas'
]

artists_00s = [
    '50 Cent',
    'Nelly',
    'Lil Wayne',
    'Missy Elliot',
    'T.I.',
    'Eminem',
    'Ludacris',
    'Xzibit',
    'The Game',
    'Kanye West'
]

artists_10s = [
    'Lil Uzi Vert',
    'Drake',
    'Kendrick Lamar',
    'Migos',
    'Travis Scott',
    'Lil Pump',
    'Travis Scott',
    'Nicki Minaj',
    'Young Thug',
    'A$AP Rocky'
]

# %%
artist_list = artists_80es + artists_90es + artists_00s + artists_10s
num_songs = 50

# %%
def download_artists_lyrics(artist_list, num_songs, save_dict='./data/')
    for artist_item in artists_list:
        artist = genius.search_artist(artist_item, sort='popularity', max_songs=num_songs, get_full_info=True)
        artist.save_lyrics(os.path.join(save_dict, artist_item+'_lyrics.json'))
# Out:
# Run-D.M.C.
# Beastie Boys
# LL Cool J
# Big Daddy Kane
# Ice T
# Rakim
# Biz Markie
# 2Pac
# The Notorious B.I.G.
# Busta Rhymes
# Snoop Dogg
# DMX
# Outkast
# Puff Daddy
# Ice Cube
# Jay Z
# Nas
# 50 Cent
# Nelly
# Lil Wayne
# Missy Elliot
# T.I.
# Eminem
# Ludacris
# Xzibit
# The Game
# Kanye West
# Lil Uzi Vert
# Drake
# Kendrick Lamar
# Migos
# Travis Scott
# Lil Pump
# Travis Scott
# Nicki Minaj
# Young Thug
# A$AP Rocky

# %%
artist = genius.search_artist('Kendrick Lamar', sort='popularity', max_songs=5, get_full_info=True)
# Out:
# Searching for songs by Kendrick Lamar...
#
# Song 1: "HUMBLE."
# Song 2: "​m.A.A.d city"
# Song 3: "Swimming Pools (Drank)"
# Song 4: "DNA."
# Song 5: "Money Trees"
#
# Reached user-specified song limit (5).
# Done. Found 5 songs.

# %%
song1 = artist.songs[1]

# %%
print(song.lyrics.replace('in\'', 'ing'))
# Out:
# [Part I: Produced by Sounwave]
#
# [Intro: Kendrick Lamar & ScHoolboy Q]
# If Pirus and Crips all got along
# They'd probably gun me down by the end of this song
# Seem like the whole city go against me
# Every time I'm in the street, I hear—
# YAWK! YAWK! YAWK! YAWK!
#
# [Chorus]
# Man down, where you from, nigga?
# Fuck who you know—where you from, my nigga?
# Where your grandma stay, huh, my nigga?
# This m.A.A.d city I run, my nigga
#
# [Verse 1: Kendrick Lamar]
# Brace yourself, I'll take you on a trip down memory lane
# This is not a rap on how I'm slinging crack or move cocaine
# This is cul-de-sac and plenty Cognac and major pain
# Not the drill sergeant, but the stress that weighing on your brain
# It was me, L Boog, and Yan Yan, YG Lucky ride down Rosecrans
# It got ugly, waving yo' hand out the window – check yourself!
# Uh, Warriors and Conans, hope euphoria can slow dance
# With society, the driver seat the first one to get killed
# ...

# %%
song.album
# Out:
# 'good kid, m.A.A.d city (Deluxe Version)'

# %%
song1.album

# %%
artist.save_lyrics()
# Out:
# Wrote 5 songs to Lyrics_KendrickLamar.json.
# {'songs': [{'title': 'HUMBLE.',
#    'album': None,
#    'year': None,
# ...
