# %%
import lyricsgenius
import os

# %%
genius = lyricsgenius.Genius('C4lb2FuFPCOkthatVzo3IuuVTJO_a2Q5sOd6_tI2Z1EabzHfvxcj15pJ1H-PivEX')

# %%
artist_gangster_rap = [
    'Kool Savas',
    'Sido',
    'B_Tight',
    'Bushido',
    'Eko Fresh',
    'Frauenarzt',
    'Bass Sultan Hengzt',
    'K.I.Z',
    'Massiv',
    'Kollegah',
    'Haftbefehl'
]

artist_cloud_rap = [
    'Crack Ignaz',
    'Yung Hurn',
    'RIN',
    'Eunique',
    'Money Boy',
    'Hustensaft Jüngling',
    'LGoony',
    'Haiyti'
]

artist_afro_trap = [
    'Capital Bra',
    'Nimo',
    'Miami Yacine',
    'Bonez MC & RAF Camora',
    'reezy',
    'Bausa',
    'Ufo361'
]


artist_emo = [
    'Casper',
    'Die Orsons',
    'Cro',
    'Marteria' 
]

artist_90er = [
    #'Die Fantastischen Vier',
    'Fettes Brot',
    'Advanced Chemistry',
    'Stieber Twins',
    'Cora E.',
    'Massive Töne',
    'Freundeskreis',
    'Beginner'
]

# %%
def download_artists_lyrics(artist_list, num_songs, save_dir='../data/'):
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)
    
    for artist_item in artist_list:
        artist = genius.search_artist(artist_item, sort='popularity', max_songs=num_songs, get_full_info=True)
        artist.save_lyrics(os.path.join(save_dir, artist_item+'_lyrics.json'))

# %%
artist_list = artist_90er
num_songs = 100

# %%
download_artists_lyrics(artist_list, num_songs, '../data/deutsch')
# Out:
# Searching for songs by Fettes Brot...
#
# Song 1: "Jein"
# Song 2: "Für Immer Immer"
# Song 3: "An Tagen wie diesen"
# Song 4: "Echo"
# Song 5: "Nordisch By Nature"
# Song 6: "Schwule Mädchen"
# Song 7: "Da Draussen"
# Song 8: "Bettina, Zieh Dir Bitte Etwas An"
# Song 9: "Crazy World"
# Song 10: "Emanuela"
# Song 11: "Toten Manns Disco"
# Song 12: "Kannste Kommen"
# Song 13: "Wackelige Angelegenheit"
# Song 14: "Die Meisten Meiner Feinde"
# Song 15: "Von der Liebe"
# Song 16: "Amsterdam"
# Song 17: "Tanzverbot"
# Song 18: "Dynamit & Farben"
# Song 19: "Silberfische In Meinem Bett"
# Song 20: "KussKussKuss"
# Song 21: "Teenager vom Mars"
# Song 22: "Kalte Füsse"
# Song 23: "Meh' Bier"
# Song 24: "Wildwechsel"
# Song 25: "Das letzte Lied auf der Welt"
# Song 26: "The Grosser"
# Song 27: "Erdbeben"
# Song 28: "Ich lass dich nicht los"
# Song 29: "Sekt oder Selters"
# Song 30: "Können Diese Augen Lügen?"
# Song 31: "Meine Stimme"
# Song 32: "Automatikpistole"
# Song 33: "Ganz Schön Low"
# ...

# %%
artists_80es = [
    #'Run-D.M.C.',
    #'Beastie Boys',
    #'LL Cool J',
    #'Big Daddy Kane',
    #'Ice T',
    #'Rakim',
    #'Biz Markie'
]

artists_90es = [
    #'2Pac',
    #'The Notorious B.I.G.',
    #'Busta Rhymes',
    #'Snoop Dogg',
    #'DMX',
    #'Outkast',
    #'Puff Daddy',
    #'Ice Cube',
    #'Jay Z',
    #'Nas'
]

artists_00s = [
    #'50 Cent',
    #'Nelly',
    #'Lil Wayne',
    #'Missy Elliot',
    #'T.I.',
    'Eminem',
    'Ludacris',
    'Xzibit',
    'The Game',
    'Kanye West'
]

artists_10s = [
    'Lil Uzi Vert',
    'Drake',
    'Kendrick Lamar',
    'Migos',
    'Travis Scott',
    'Lil Pump',
    'Travis Scott',
    'Nicki Minaj',
    'Young Thug',
    'A$AP Rocky'
]
